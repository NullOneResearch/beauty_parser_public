# %%
def handle_goldapple():
    
def handle_letu():
    
def handle_rivegauche():
    
def handle_iledebeaute():
    
def handle_podrygka():

# %%
import pandas as pd

import sqlite3

# Read sqlite query results into a pandas DataFrame
con = sqlite3.connect("russian_beauty_parser.db")
df = pd.read_sql_query("SELECT * from cosmetics", con)

# Verify that result of SQL query is stored in the dataframe
print(df.head())

con.close()
# Out:
# B:\python\lib\site-packages\pandas\compat\_optional.py:138: UserWarning: Pandas requires version '2.7.0' or newer of 'numexpr' (version '2.6.9' currently installed).
#   warnings.warn(msg, UserWarning)
#                                         product_name  price      brand  \
# 0                ВВ-крем для любого типа кожи тон 01  399.0   ACHROMIN
# 1                ВВ-крем для любого типа кожи тон 02  399.0   ACHROMIN
# 2  Тональный ВВ Крем с Защитой от cолнца под тон ...  550.0   LEBELAGE
# 3                    ВВ крем гиалуроновый ALL in ONE  636.0  LIBREDERM
# 4     ВВ-крем Nude perfector с гиалуроновой кислотой  538.0  BEAUTIFIC
#
#                                     comment inside_code  \
# 0                     Уход за лицом | 50 мл   112300030
# 1                     Уход за лицом | 50 мл   112300029
# 2                    BB&CC средства | 30 мл   116600582
# 3                     Уход за лицом | 50 мл   106800213
# 4  Уход за лицом | №2 теплый бежевый, 30 мл   124900751
#
#                                                  url date_acquired  \
# 0  https://www.letu.ru/product/achromin-vv-krem-d...    2022-11-23
# 1  https://www.letu.ru/product/achromin-vv-krem-d...    2022-11-23
# 2  https://www.letu.ru/product/lebelage-tonalnyi-...    2022-11-23
# 3  https://www.letu.ru/product/librederm-vv-krem-...    2022-11-23
# 4  https://www.letu.ru/product/beautific-vv-krem-...    2022-11-23
#
#   source_seller
# 0       Летуаль
# 1       Летуаль
# 2       Летуаль
# 3       Летуаль
# 4       Летуаль

# %%
df
# Out:
#                                              product_name  price      brand  \
# 0                     ВВ-крем для любого типа кожи тон 01  399.0   ACHROMIN
# 1                     ВВ-крем для любого типа кожи тон 02  399.0   ACHROMIN
# 2       Тональный ВВ Крем с Защитой от cолнца под тон ...  550.0   LEBELAGE
# 3                         ВВ крем гиалуроновый ALL in ONE  636.0  LIBREDERM
# 4          ВВ-крем Nude perfector с гиалуроновой кислотой  538.0  BEAUTIFIC
# ...                                                   ...    ...        ...
# 135950  Блеск для губ `ISCREAM` SWEETHEART (тон 01 van...   99.0    ISCREAM
# 135951  Блеск-тинт для губ `ISCREAM` YUMMY в пауче (то...   99.0    ISCREAM
# 135952  Помада-бальзам для губ `ISCREAM` MERMAZING про...  279.0    ISCREAM
# 135953  Хайлайтер-румяна `ISCREAM` YUMMY 2 в 1 тон 03 ...   99.0    ISCREAM
# 135954  Блеск для губ `ISCREAM` CRYSTAL POWER с эффект...   99.0    ISCREAM
#
#                                          comment inside_code  \
# 0                          Уход за лицом | 50 мл   112300030
# 1                          Уход за лицом | 50 мл   112300029
# 2                         BB&CC средства | 30 мл   116600582
# 3                          Уход за лицом | 50 мл   106800213
# 4       Уход за лицом | №2 теплый бежевый, 30 мл   124900751
# ...                                          ...         ...
# 135950                        Макияж/Губы/Блески      189757
# 135951                          Макияж/Губы/Тинт      189755
# 135952                        Макияж/Губы/Помада      187367
# 135953                    Макияж/Лицо/Хайлайтеры      187297
# 135954                        Макияж/Губы/Блески      188426
#
#                                                       url date_acquired  \
# 0       https://www.letu.ru/product/achromin-vv-krem-d...    2022-11-23
# 1       https://www.letu.ru/product/achromin-vv-krem-d...    2022-11-23
# 2       https://www.letu.ru/product/lebelage-tonalnyi-...    2022-11-23
# 3       https://www.letu.ru/product/librederm-vv-krem-...    2022-11-23
# 4       https://www.letu.ru/product/beautific-vv-krem-...    2022-11-23
# ...                                                   ...           ...
# 135950   https://www.podrygka.ru/catalog/makiyazh/guby...    2022-11-23
# 135951   https://www.podrygka.ru/catalog/makiyazh/guby...    2022-11-23
# 135952   https://www.podrygka.ru/catalog/makiyazh/guby...    2022-11-23
# 135953   https://www.podrygka.ru/catalog/makiyazh/lits...    2022-11-23
# 135954   https://www.podrygka.ru/catalog/makiyazh/guby...    2022-11-23
#
#        source_seller
# 0            Летуаль
# 1            Летуаль
# 2            Летуаль
# 3            Летуаль
# 4            Летуаль
# ...              ...
# 135950      Подружка
# 135951      Подружка
# 135952      Подружка
# 135953      Подружка
# 135954      Подружка
#
# [135955 rows x 8 columns]
